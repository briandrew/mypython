# %%
import pandas as pd
csv_path = 'customer.csv'
df=pd.read_csv(csv_path)
df.head() # first 5 rows of a data frame
# Out:
#    CustomerID  NameStyle Title FirstName MiddleName    LastName Suffix  \
# 0           1      False   Mr.   Orlando         N.         Gee    NaN
# 1           2      False   Mr.     Keith        NaN      Harris    NaN
# 2           3      False   Ms.     Donna         F.    Carreras    NaN
# 3           4      False   Ms.     Janet         M.       Gates    NaN
# 4           5      False   Mr.      Lucy        NaN  Harrington    NaN
#
#                   CompanyName               SalesPerson  \
# 0                A Bike Store   adventure-works\pamela0
# 1          Progressive Sports    adventure-works\david8
# 2    Advanced Bike Components  adventure-works\jillian0
# 3       Modular Cycle Systems  adventure-works\jillian0
# 4  Metropolitan Sports Supply      adventure-works\shu0
#
#                    EmailAddress         Phone  \
# 0  orlando0@adventure-works.com  245-555-0173
# 1    keith0@adventure-works.com  170-555-0127
# 2    donna0@adventure-works.com  279-555-0130
# ...

# %%
y=df[["FirstName", 'MiddleName', 'LastName']]
y
# Out:
#     FirstName MiddleName    LastName
# 0     Orlando         N.         Gee
# 1       Keith        NaN      Harris
# 2       Donna         F.    Carreras
# 3       Janet         M.       Gates
# 4        Lucy        NaN  Harrington
# ..        ...        ...         ...
# 842      Raja         D.   Venugopal
# 843      Dora         P.      Verdad
# 844     Wanda         F.      Vernon
# 845    Robert         R.       Vessa
# 846  Caroline         A.    Vicknair
#
# [847 rows x 3 columns]

# %%
df.iloc[0,0]:1 # reference first row, first column
df.iloc[0,2]:  # access first row, 3rd column
df.iloc[1,2]:  # access 2nd row, 3rd column
or
df.iloc[0,'CustomerID']: # also access first row, first column
df.iloc[2, 'FirsName']: # access 3rd row, 4th column

# %%
z = df.iloc[0:8, 0:8] # creates a slice using rows, columns
z
# Out:
#    CustomerID  NameStyle Title FirstName MiddleName    LastName Suffix  \
# 0           1      False   Mr.   Orlando         N.         Gee    NaN
# 1           2      False   Mr.     Keith        NaN      Harris    NaN
# 2           3      False   Ms.     Donna         F.    Carreras    NaN
# 3           4      False   Ms.     Janet         M.       Gates    NaN
# 4           5      False   Mr.      Lucy        NaN  Harrington    NaN
# 5           6      False   Ms.  Rosmarie         J.     Carroll    NaN
# 6           7      False   Mr.   Dominic         P.        Gash    NaN
# 7          10      False   Ms.  Kathleen         M.       Garza    NaN
#
#                   CompanyName
# 0                A Bike Store
# 1          Progressive Sports
# 2    Advanced Bike Components
# 3       Modular Cycle Systems
# 4  Metropolitan Sports Supply
# 5    Aerobic Exercise Company
# 6            Associated Bikes
# 7        Rural Cycle Emporium

# %%
# Listing unique values using panda 'unique'
df['LastName'].unique() # generates array of all unique last names
# Out:
# array(['Gee', 'Harris', 'Carreras', 'Gates', 'Harrington', 'Carroll',
#        'Gash', 'Garza', 'Harding', 'Caprio', 'Beck', 'Liu', 'Beaver',
#        'Handley', 'Burnett', 'Hanif', 'Blanton', 'Blackwell', 'Hamilton',
#        'Logan', 'German', 'Geist', 'Haines', 'Looney', 'Gehring',
#        'Hagens', 'Los', 'Leavitt', 'Lawrence', 'Haemon', 'Lucerne',
#        'Laszlo', 'Lang', 'Groth', 'Lundahl', 'Kurniawan', 'Groncki',
#        'Lunt', 'Kurtz', 'Kuppa', 'Greer', 'Deborde', 'Kumar', 'Krupka',
#        'Bright', 'Delaney', 'Krow', 'Brundage', 'Delmarco', 'Kennedy',
#        'Kramer', 'Brumfield', 'Demott Jr', 'Kotc', 'Koski', 'Carmody',
#        'Desai', 'Konersmann', 'Carmichael', 'Lepro', 'Kogan', 'King',
#        'Conner', 'Leste', 'Thomsen', 'Thompson', 'Colvin', 'Lewin',
#        'Colon', 'Li', 'Thomas', 'Coleman', 'Lique', 'Thames', 'Coffman',
#        'Lisboa', 'Tench', 'Cobb', 'Graff', 'Graham', 'Barzdukas',
# ...

# %%
z.to_csv('test-to.csv') # took z and created a new csv from it, so cool

# %%
#Define a dictionary 'x'

x = {'Name': ['Rose','John', 'Jane', 'Mary'], 'ID': [1, 2, 3, 4], 'Department': ['Architect Group', 'Software Group', 'Design Team', 'Infrastructure'], 
      'Salary':[100000, 80000, 50000, 60000]}

#casting the dictionary to a DataFrame
df = pd.DataFrame(x)

#display the result df
df
# Out:
#    Name  ID       Department  Salary
# 0  Rose   1  Architect Group  100000
# 1  John   2   Software Group   80000
# 2  Jane   3      Design Team   50000
# 3  Mary   4   Infrastructure   60000

# %%
#Retrieving the "ID" column and assigning it to a variable x
x = df[['ID']]
x
# Out:
#    ID
# 0   1
# 1   2
# 2   3
# 3   4

# %%
#check the type of x
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
#Retrieving the Department, Salary and ID columns and assigning it to a variable z

z = df[['Department','Salary','ID']]
z
# Out:
#         Department  Salary  ID
# 0  Architect Group  100000   1
# 1   Software Group   80000   2
# 2      Design Team   50000   3
# 3   Infrastructure   60000   4

# %%
# create data frame from provided info in exercise
y = { 'Student': ['David', 'Samuel', 'Terry', 'Evan'], 'Age': [27,24, 22,32], 'Country':['UK', 'Canada', 'China', 'USA'], 
     'Course': ['Python', 'Data Structures', 'Machine Learning', 'Web Development'], 'Marks':[85,72,89,76]}
df = pd.DataFrame(y)
df
# Out:
#   Student  Age Country            Course  Marks
# 0   David   27      UK            Python     85
# 1  Samuel   24  Canada   Data Structures     72
# 2   Terry   22   China  Machine Learning     89
# 3    Evan   32     USA   Web Development     76

# %%
c = df[['Marks']]
c
# Out:
#    Marks
# 0     85
# 1     72
# 2     89
# 3     76

# %%
c = df[['Country', 'Marks']]
c
# Out:
#   Country  Marks
# 0      UK     85
# 1  Canada     72
# 2   China     89
# 3     USA     76

# %% [markdown]
# ### Exercise 2: <code>loc()</code> and <code>iloc()</code> functions
#
# <code>loc()</code> is a label-based data selecting method which means that we have to pass the name of the row or column that we want to select. This method includes the last element of the range passed in it.
#
# Simple syntax for your understanding:
#
#  - loc[row_label, column_label]
#
# <code>iloc()</code> is an indexed-based selecting method which means that we have to pass an integer index in the method to select a specific row/column. This method does not include the last element of the range passed in it.
#
# Simple syntax for your understanding:
#
#  - iloc[row_index, column_index]
#
# <h4 id="data">Let us see some examples on the same.</h4>

# %%
# Access the value on the first row and the first column

df.iloc[0, 0]
# Out:
# 'David'

# %%
# Access the value on the first row and the third column

df.iloc[0,2]
# Out:
# 'UK'

# %%
df2=df
df2=df2.set_index("Student")

# %%
#To display the first 5 rows of new dataframe
df2.head()
# Out:
#          Age Country            Course  Marks
# Student
# David     27      UK            Python     85
# Samuel    24  Canada   Data Structures     72
# Terry     22   China  Machine Learning     89
# Evan      32     USA   Web Development     76

# %%
#Now, let us access the column using the name
df2.loc['Terry', 'Marks']
# Out:
# 89

# %%
df2.iloc[2,3]
# Out:
# 89

# %%
df.iloc[0:2, 0:3]
# Out:
#   Student  Age Country
# 0   David   27      UK
# 1  Samuel   24  Canada

# %%
#let us do the slicing using loc() function on old dataframe df where index column is having labels as 0,1,2
df.loc[0:2,'Age':'Course']
# Out:
#    Age Country            Course
# 0   27      UK            Python
# 1   24  Canada   Data Structures
# 2   22   China  Machine Learning

# %%
#let us do the slicing using loc() function on new dataframe df2 where index column is Name having labels: Rose, John and Jane
df2.loc['Samuel':'Evan', 'Country':'Marks']
# Out:
#         Country            Course  Marks
# Student
# Samuel   Canada   Data Structures     72
# Terry     China  Machine Learning     89
# Evan        USA   Web Development     76

# %%
# Write your code below and press Shift+Enter to execute
df.loc[0:4, 'Age':'Marks']
# Out:
#    Age Country            Course  Marks
# 0   27      UK            Python     85
# 1   24  Canada   Data Structures     72
# 2   22   China  Machine Learning     89
# 3   32     USA   Web Development     76
